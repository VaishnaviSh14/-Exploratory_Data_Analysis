# %% [markdown]
# Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the
# dataset have?

# %%
##Ans 1. 
import pandas as pd
df = pd.read_excel('flight_price.xlsx')
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
num_rows, num_columns = df.shape
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")
# Out:
# Number of rows: 10683
# Number of columns: 11

# %% [markdown]
# Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the
# distribution.

# %%
#Ans. 2
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot (data = df , kde = True , x= 'Price')
plt.title('Distribution of Flight Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# Q3. What is the range of prices in the dataset? What is the minimum and maximum price?

# %%
#Ans 3.
prices = df['Price']

min_price = prices.min()
max_price = prices.max()
price_range = max_price - min_price

print(f"Minimum Price: {min_price}")
print(f"Maximum Price: {max_price}")
print(f"Price Range: {price_range}")
# Out:
# Minimum Price: 1759
# Maximum Price: 79512
# Price Range: 77753

# %% [markdown]
# Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different
# airlines.

# %%
#Ans.
plt.figure(figsize = (35,10))
sns.catplot(x = 'Airline', data = df , y = 'Price' , kind = 'box')
plt.title('Flight Prices by Airline (Box Plot)')
plt.xlabel('Airline')
plt.ylabel('Price')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how
# they may impact your analysis.

# %%
#Ans.
sns.catplot(x = 'Price' , data = df , kind = 'box')

# %% [markdown]
# There are a lot of outliers specillay between 2000 to 3000.
# Outliers can significantly affect the mean (average) of a dataset, pulling it in the direction of the outlier
# Outliers can impact the range, standard deviation, and interquartile range, making these measures less reflective of the actual variability within the majority of the data.
# Outliers can affect the performance and accuracy of predictive models.
# Outliers can skew visualizations, making it challenging to see patterns or trends within the main bulk of the data.

# %% [markdown]
# Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset
# to identify the peak travel season. What features would you analyze to identify the peak season.

# %%
#Ans.
#Let's seperate the date so we can see in which month we have the highest number of travels
df['month'] = df['Date_of_Journey'].str.split('/').str[1]

# %%
sns.lineplot(y = 'Price',x = 'Airline' , hue ='month', data = df)
plt.xlabel('Airlines')
plt.ylabel('Price')
plt.xticks(rotation = 90)
plt.tight_layout()

# %% [markdown]
# Features Analyzed - Date of Journey, Price
# We can analyse that month of March is the peak season.

# %% [markdown]
# Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight
# Price dataset to identify any trends in flight prices. What features would you analyze to identify these
# trends, and what visualizations would you use to present your findings to your team?

# %% [markdown]
# Features to Analyze:
# Date of Journey: Investigate how flight prices change over different months or days.
#
# Source and Destination: Analyze if flight prices vary based on the origin and destination cities.
#
# Airline: Explore the impact of different airlines on flight prices.
#
# Total Stops: Examine how the number of stops affects flight prices.
#
# Additional Info: Investigate if additional information affects flight prices.
#
# Duration of Journey: Analyze how the duration of the flight affects prices.
#
# Visualizations:
#
# Box Plots:
# Create box plots to visualize the distribution of flight prices for different categorical features like airlines, source, and destination.
# This reveals the median, quartiles, and potential outliers for each category.
#
# Scatter Plots:
# Plot scatter plots to show the relationship between continuous features (like flight duration) and flight prices.
# This helps identify any linear or nonlinear correlations.
#
# Bar Plots:
# Create bar plots to show the average flight prices for different categories, such as airlines or the number of stops.
# This provides a clear comparison between different categories.
#
# Heatmaps:
# Use a heatmap to show the correlation between features and flight prices.
# This helps identify which features have stronger relationships with prices.
#
# Pair Plots:
# Generate pair plots to visualize scatter plots for multiple features against flight prices.
# This allows you to identify potential relationships among multiple features.

# %% [markdown]
# Q8. You are a data scientist working for an airline company, and you have been asked to analyze the
# Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to
# identify these factors, and how would you present your findings to the management team?

# %% [markdown]
# #Ans
# Features to Analyze:
#
# 1. Date of Journey: Investigate how flight prices change over different months or seasons.
#
# 2. Source and Destination: Analyze if flight prices vary based on the origin and destination locations.
#
# 3. Total Stops: Examine how the number of stops affects flight prices.
#
# 4. Airline: Explore the impact of different airlines on flight prices.
#
# 5. Duration of Journey: Analyze if flight duration affects prices.
#
# Approach to Present Findings:
#
# Executive Summary:
# Start with a brief summary of your analysis and the objective of identifying factors affecting flight prices.
#
# Key Insights:
# Highlight the key insights discovered, such as factors that significantly influence flight prices.
#
# Methodology:
# Explain the steps took to analyze the data, including data preprocessing and feature engineering.
#
# Visualizations:
# Present visualizations for each analyzed feature, demonstrating trends and patterns.
# Use scatter plots, box plots, line plots, or bar plots to effectively show the relationships between features and prices.
#
# Correlation Analysis:
# Present correlation matrices to show the strength and direction of relationships between features and prices.Correlation Analysis:

# %% [markdown]
# Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does
# the dataset have?

# %%
#Ans 9.
df1 =pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')

# %%
df1.shape
# Out:
# (10841, 13)

# %% [markdown]
# Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different
# app categories.

# %%
df1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
sns.catplot(x= 'Category' , y= 'Rating' ,data = df1 ,  kind = 'box')
plt.xticks(rotation = 90)
plt.tight_layout()
plt.subplots_adjust(bottom=0.2)

# %% [markdown]
# Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may
# impact your analysis.

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# month              0
# dtype: int64

# %% [markdown]
# Observations - yes there are missing values in the dataset
#
# The "Route" column has one missing value.
# The "Total_Stops" column has one missing value.
# All other columns in the dataset do not have any missing values.
#
# **They can impact my analysis as
# For the "Route" column, since only one value is missing, its impact on analysis might be minimal, especially if we do not heavily focusing on specific flight routes.
# Similarly, the one missing value in the "Total_Stops" column may not significantly impact our analysis if this information is not central to our research.

# %% [markdown]
# Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize
# the relationship.

# %%
df2 = pd.read_csv('google_cleaned.csv')
sns.scatterplot(x = 'Rating' , y= 'Size' , data = df2)
plt.xlabel('Size')
plt.ylabel('Ratings')
plt.title('Relationship between size and rating')
# Out:
# Text(0.5, 1.0, 'Relationship between size and rating')

# %% [markdown]
# #Observations - We can see that there is a strong relationship between size and ratings
# also we can see that ratings are highest when app size is between 4.0 to 4.6

# %% [markdown]
# Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.

# %%
sns.barplot(x = 'Type' , y= 'Price' ,data = df2)
# Out:
# <AxesSubplot: xlabel='Type', ylabel='Price'>

# %% [markdown]
# Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps
# with the highest number of installs.

# %%
freq_table = pd.crosstab(df2['App'], 'Installs')
top_10_apps = freq_table.sort_values(by='Installs', ascending=False).head(10)
print(freq_table)
# Out:
# col_0                                             Installs
# App
# "i DT" Fútbol. Todos Somos Técnicos.                     1
# +Download 4 Instagram Twitter                            1
# - Free Comics - Comic Apps                               1
# .R                                                       1
# /u/app                                                   1
# ...                                                    ...
# 뽕티비 - 개인방송, 인터넷방송, BJ방송                                  1
# 💎 I'm rich                                               1
# 💘 WhatsLov: Smileys of love, stickers and GIF            1
# 📏 Smart Ruler ↔️ cm/inch measuring for homework!         1
# 🔥 Football Wallpapers 4K | Full HD Backgrounds 😍         1
#
# [9659 rows x 1 columns]

# %% [markdown]
# Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the
# Google Playstore dataset to identify the most popular app categories. How would you approach this
# task, and what features would you analyze to make recommendations to the company?

# %% [markdown]
# Data Collection and Preparation:
# Obtain the Google Playstore dataset, which should include information about apps such as their category, ratings, reviews, download counts, and other relevant attributes. Ensure that the data is clean, without missing values or duplicates.
#
# Exploratory Data Analysis (EDA):
# Conduct an initial exploration of the dataset to get a sense of its structure and contents. This may involve summary statistics, data visualization and identifying any outliers or inconsistencies.
#
# Identify App Categories:
# Start by analyzing the available app categories in the dataset. This will provide insight into the diversity of apps available on the Playstore.
